# %%
import pandas as pd

# %%
ebe_df = pd.read_csv(r'../experiments\ebe_vs\ebe-models\ebe_Results_final.csv')
ebe_df.head()
# Out:
#    Unnamed: 0   id  batch_size  \
# 0           1   52        1024
# 1           5  115         128
# 2           6  131         128
# 3           0   44         128
# 4           8  139        1024
#
#                                          n_instances  epochs_trained  \
# 0  [54, 108, 216, 432, 864, 1080, 1080, 1080, 108...              19
# 1  [54, 108, 216, 432, 864, 1080, 1080, 1080, 108...              18
# 2  [54, 108, 216, 432, 864, 1080, 1080, 1080, 108...              17
# 3  [54, 108, 216, 432, 864, 1080, 1080, 1080, 108...              19
# 4  [54, 108, 216, 432, 864, 1080, 1080, 1080, 108...              17
#
#                                              efforts  \
# 0  [0.1, 0.4, 1.2000000000000002, 3.2, 5.0, 6.0, ...
# 1  [0.1, 0.4, 1.2000000000000002, 3.2, 5.0, 6.0, ...
# 2  [0.1, 0.4, 1.2000000000000002, 3.2, 5.0, 6.0, ...
# 3  [0.1, 0.4, 1.2000000000000002, 3.2, 5.0, 6.0, ...
# 4  [0.1, 0.4, 1.2000000000000002, 3.2, 5.0, 6.0, ...
#
# ...
